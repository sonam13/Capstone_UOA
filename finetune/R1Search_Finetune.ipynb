# %%
# downloads ~958 KB
# !wget -O financebench_merged.jsonl \
https://huggingface.co/datasets/PatronusAI/financebench/raw/main/financebench_merged.jsonl
# Out:
# --2025-08-28 16:04:46--  https://huggingface.co/datasets/PatronusAI/financebench/raw/main/financebench_merged.jsonl
# Resolving huggingface.co (huggingface.co)... 18.239.50.80, 18.239.50.16, 18.239.50.103, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 958087 (936K) [text/plain]
# Saving to: ‘financebench_merged.jsonl’
#
# financebench_merged 100%[===================>] 935.63K  5.36MB/s    in 0.2s
#
# 2025-08-28 16:04:46 (5.36 MB/s) - ‘financebench_merged.jsonl’ saved [958087/958087]

# %%
# !wc -l financebench_merged.jsonl   # should be 150 lines
# !head -n 2 financebench_merged.jsonl
# Out:
# 150 financebench_merged.jsonl
# ...

# %%
# !python make_financebench_eval_jsonl.py
# !head -n 2 financebench_eval.jsonl
# Out:
# Wrote financebench_eval.jsonl
# {"question": "What is the FY2018 capital expenditure amount (in USD millions) for 3M? Give a response to the question by relying on the details shown in the cash flow statement.", "answer": "$1577.00", "company": "3M", "doc_name": "3M_2018_10K", "doc_type": "10k", "doc_period": 2018, "doc_link": "https://investors.3m.com/financials/sec-filings/content/0001558370-19-000470/0001558370-19-000470.pdf"}
# {"question": "Assume that you are a public equities analyst. Answer the following question by primarily using information that is shown in the balance sheet: what is the year end FY2018 net PPNE for 3M? Answer in USD billions.", "answer": "$8.70", "company": "3M", "doc_name": "3M_2018_10K", "doc_type": "10k", "doc_period": 2018, "doc_link": "https://investors.3m.com/financials/sec-filings/content/0001558370-19-000470/0001558370-19-000470.pdf"}
